# %% [markdown]
# <a href="https://colab.research.google.com/github/pepesoul/My_First_Test_Repo/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
#
# Нужно сделать:
#
#
#
# 1.   Список.
# 2.   Рисунок.
# 3.   Таблица.
# 4.   Ссылка.
#
# ![image.png](data:image/png;base64,...)
#
# \begin{array}{c}
# A & B & C \\\hline
# 11 & 22 & 33 \\
# 1000 & 250 & -50 \\
# \end{array}
#
#
#
# [Ссылка по руководству по Markdown](https://bbb-records.edu.nstu.ru/playback/presentation/2.3/62b55fdb368345829ce701ec38427212ed73960c-1626771121132?meetingId=62b55fdb368345829ce701ec38427212ed73960c-1626771121132)
